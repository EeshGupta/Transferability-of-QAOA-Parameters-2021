# %% [markdown]
# Imports

# %%
import warnings
warnings.filterwarnings('ignore')

#################
# My notebook issues
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
sys.path.append('home/egupta/.local/bin')

##############

import os
import numpy as np
import scipy.stats as ss
import networkx as nx
import csv 
import numpy as np
import seaborn as sns
from pandas import DataFrame
from scipy.optimize import curve_fit
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline

##qtensor imports
import qtensor
from qtensor import QAOA_energy
from qtensor import parameter_optimization as popt
import torch
# Out:
# 2021-07-20 10:34:06,538- WARNING•	QuickBB solver is unavailable
# 2021-07-20 10:34:06,540- WARNING•	Tamaki solver is unavailable: No path /home/egupta/.local/lib/python3.7/site-packages/thirdparty/tamaki_treewidth

# %% [markdown]
# # Grabbing Graphs

# %%
g_data = np.loadtxt("LocalOptima20NodeData.txt").reshape(22,20,3)

# %%
max_en =[]
for i in range(len(g_data)):
    en = ma

# %%
def mats_to_graphs(mat_list):
  """
  Given list of adjaceny matrix repr of graphs, converts to actual graphs
  """
  g_list = []
  for mat in mat_list:
    G = nx.convert_matrix.from_numpy_matrix(mat)
    g_list.append(G)
  return g_list

# %%
matrix_list = np.loadtxt("LocalOptima20NodesGraphs.txt").reshape(22,20,20)

# %%
g_list = mats_to_graphs(matrix_list)

# %% [markdown]
# Finding Max Energies

# %%
def find_max(data):
    """
    Return an array with best optima of each graph
    """
    max_en = []
    n = len(data)
    
    for i in range(n):
        max_enn = 0
        for j in range(len(data[i])):
            enn = data[i][j][2]
            if enn>max_enn:
                max_enn = enn
        max_en.append(max_enn)
    return max_en

# %%
max_en = find_max(g_data)

# %%
max_en
# Out:
# [20.284749105357,
#  20.502635957333265,
#  18.066398420868616,
#  17.86002664293571,
#  20.864235941178393,
#  20.858653068078425,
#  23.98091762961151,
#  23.838427672430818,
#  22.221382432411353,
#  22.068496008578585,
#  26.780676083932054,
#  26.679933251721188,
#  23.457681076270216,
#  23.257166818897765,
#  22.915545653484855,
#  23.07986833586874,
#  21.812862017619985,
#  21.96574473687561,
#  26.79304276289154,
#  27.1833368319099,
#  27.66213945619826,
#  27.8452127364304]

# %% [markdown]
# # Computing Similarities of a subset of graphs

# %%
ind = [2*i for i in range(11)]
#ind = [1,7,14,20]

# %%
graphs = [g_list[i] for i in ind]
graphs_data = [g_data[i] for i in ind]
graphs_max_en= [max_en[i] for i in ind]

# %%
def run(graphs = graphs, g_data = graphs_data, g_max_en = graphs_max_en):
  """
  For each graph pair, returns all multistart approx ratios 
  """
  a_sim = []
  seeds = 20
  full_data = []
  averaged_data = []

  n = len(graphs)
  for i in range(n):
    donor = graphs[i]
    print('########################')
    print(i)

    for j in range(n):
      print('***')
      print(j)
      if True:
        acceptor = graphs[j]
        acceptor_max = g_max_en[j]

        av = 0

        for k in range(seeds):

          donor_gamma = g_data[i][k][0]
          donor_beta = g_data[i][k][1]
          
          
          y = QAOA_energy(acceptor, gamma = [donor_gamma], beta = [donor_beta])
          a_r = y/acceptor_max
          full_data.append(a_r)
          print(a_r)
          av += a_r
        avg = av/seeds
        averaged_data.append(avg)
  return full_data, averaged_data

# %%
full, av = run()
# Out:
# ########################
# 0
# ***
# 0
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999995]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999985]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999998]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999996]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [0.99999998]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=31.0, style=ProgressStyle(descriptio…
# [1.]
# ***
# 1
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=27.0, style=ProgressStyle(descriptio…
# [0.99828595]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=27.0, style=ProgressStyle(descriptio…
# [0.99828076]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=27.0, style=ProgressStyle(descriptio…
# [0.99828435]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=27.0, style=ProgressStyle(descriptio…
# [0.99828414]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=27.0, style=ProgressStyle(descriptio…
# [0.

# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99745756]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99745603]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99745647]
# ***
# 5
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99097643]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99094237]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99097431]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99097569]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99092937]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.9909879]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78581778]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99090499]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78582677]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78582601]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78582626]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78582786]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99098154]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78576863]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99097657]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78582626]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78582644]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99098603]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99098316]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99098387]
# ***
# 6
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661052]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99658904]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661129]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661191]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99658075]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661665]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69749489]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99656293]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69750401]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69750572]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69750453]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69750674]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661416]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69744104]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661225]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69750517]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.69750478]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661666]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99661484]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.996615]
# ***
# 7
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99424495]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99422181]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99423538]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99423729]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99421328]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.9942569]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65444347]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99420581]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65446161]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65444367]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65445365]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65445296]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99424683]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65437495]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99423872]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65444942]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.65445353]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99425111]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99424921]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99425078]
# ***
# 8
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99793777]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99792691]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99792731]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# ...
# [0.99639546]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99639808]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.74477044]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.74476955]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.74477036]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.74477037]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99641547]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99640449]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99639536]
# ***
# 5
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969289]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404816]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78403812]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969326]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969083]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404821]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.9996978]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78403398]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404633]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969182]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404794]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.9996929]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969435]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404824]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404791]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404802]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.78404826]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99970042]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969794]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=42.0, style=ProgressStyle(descriptio…
# [0.99969288]
# ***
# 6
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99703932]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84677084]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676918]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99704002]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99703496]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676712]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99704948]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676939]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.8467672]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99703705]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676548]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99703938]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.9970424]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676679]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84677185]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676578]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.84676757]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99705928]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99704987]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.9970393]
# ***
# 7
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905678]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265489]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265879]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905655]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905735]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265456]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905482]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89266046]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265533]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905706]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265454]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905683]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905634]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265452]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265507]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265453]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.89265458]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.9990611]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905493]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=36.0, style=ProgressStyle(descriptio…
# [0.99905677]
# ***
# 8
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631977]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.9311143]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.9311204]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631942]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99632042]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.93111588]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631723]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.9311225]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.93111686]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99632007]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.93111673]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631985]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631926]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.931116]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.931114]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.93111655]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.93111566]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99632891]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631745]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=34.0, style=ProgressStyle(descriptio…
# [0.99631974]
# ***
# 9
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99956026]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759629]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759159]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99955947]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99956417]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759897]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99955037]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96758899]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759782]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99956227]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759997]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99956027]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99955745]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759922]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759543]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759981]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.96759868]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99955028]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99955021]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=43.0, style=ProgressStyle(descriptio…
# [0.99956026]
# ***
# 10
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999995]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999994]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.9999999]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999998]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999994]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [0.99999994]
# HBox(children=(FloatProgress(value=0.0, description='Edge iteration', max=44.0, style=ProgressStyle(descriptio…
# [1.]

# %%
def even_percent(graph):
  """
  Determines the relative percent of even degree nodes
  """
  nodes = graph.number_of_nodes()
  tot_ev = 0
  for i in range(nodes):
    if graph.degree[i]%2 == 0:
      tot_ev+=1
  return tot_ev/nodes

ev_deg_dict ={}
n = len(graphs)
for i in range(n):
  ev_deg_dict[i] = even_percent(graphs[i])

# %%
ev_deg_dict
# Out:
# {0: 0.0,
#  1: 0.1,
#  2: 0.2,
#  3: 0.3,
#  4: 0.4,
#  5: 0.5,
#  6: 0.6,
#  7: 0.7,
#  8: 0.8,
#  9: 0.9,
#  10: 1.0}

# %%
def sort_for_plot(graphs = graphs, av_data =av , ev_deg_dict = ev_deg_dict):
  """
  For plotting purposes, creates x,y,c lists
  """
  n = len(graphs)
  seeds = 20
  x = []
  y = []
  c = []
  for i in range(n):
    
    for j in range(n):
      x.append(ev_deg_dict[i])
      y.append(ev_deg_dict[j])
      print(n)
      r = av[i*n + j]
      c.append(float(r))
  return x, y, c

# %%
x, y ,c = sort_for_plot()
# Out:
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11

# %%
c
# Out:
# [0.9999999839879112,
#  0.9811197917461916,
#  0.9707892788084267,
#  0.948066862217923,
#  0.9257686803314916,
#  0.9228756193635755,
#  0.893591934660615,
#  0.8785704427306602,
#  0.8541278762444261,
#  0.8503593059496464,
#  0.8382388050791233,
#  0.9986921069006162,
#  0.9798485771504778,
#  0.9657313636409841,
#  0.9388070185189392,
#  0.913991722554106,
#  0.9089074121738066,
#  0.8769611442284397,
#  0.8583192660062678,
#  0.8314075227767919,
#  0.8244102950704825,
#  0.8110811445192937,
#  0.9986366964566749,
#  0.9734312511990983,
#  0.9590353593153612,
#  0.9267395305932113,
#  0.8945290849677304,
#  0.8916464575849291,
#  0.8489351068985531,
#  0.8266097586451926,
#  0.7909027691272177,
#  0.787969086492949,
#  0.7706111411638055,
#  0.9980181823742955,
#  0.9721354224552373,
#  0.9582645827429239,
#  0.9275032905429645,
#  0.8949769502328238,
#  0.8933535189177032,
#  0.8498786623589805,
#  0.8279002755101679,
#  0.79232783043798,
#  0.7917565618438707,
#  0.7747939668617002,
#  0.9996722048088807,
#  0.9977286334621945,
#  0.9995854562300501,
#  0.9995915028212053,
#  0.9999992962092396,
#  0.998023650493451,
#  0.9999232074744588,
#  0.9989508077560176,
#  0.9994053983536075,
#  0.9950680395907092,
#  0.9965943422938262,
#  0.913448232776647,
#  0.9023590840730696,
#  0.9143212351216157,
#  0.9136920741367156,
#  0.9076796593002433,
#  0.9164060279993897,
#  0.9046774381324336,
#  0.9065832271433172,
#  0.9008005845337157,
#  0.9123060251951112,
#  0.9092915349437201,
#  0.7413893404934243,
#  0.7638175448485007,
#  0.8137054184277768,
#  0.8456582811060874,
#  0.8720313599464413,
#  0.890931644468395,
#  0.9240183717863204,
#  0.9450973461495551,
#  0.96326905026622,
#  0.9788104188423672,
#  0.9966935739284656,
#  0.8451196710237706,
#  0.8554796035174963,
#  0.8874014797858555,
#  0.9069552743917493,
#  0.9223727488226723,
#  0.9345317122203307,
#  0.953396446067346,
#  0.9678561089771934,
#  0.9786511640993465,
#  0.988891901491353,
#  0.9991571986049447,
#  0.7196037890513763,
#  0.7426435517960203,
#  0.7956349971785893,
#  0.8299036256363008,
#  0.8590379246376282,
#  0.8794089985081076,
#  0.9150566331713635,
#  0.9405092127908607,
#  0.9622399229146344,
#  0.9796653864355116,
#  0.997822601819985,
#  0.8208388776075044,
#  0.8302856216919643,
#  0.8676371164131826,
#  0.890915163367833,
#  0.9076123175978937,
#  0.923919533959943,
#  0.9429437783763424,
#  0.9612061062820224,
#  0.9728531800971755,
#  0.9888656369766166,
#  0.9994954701850451,
#  0.7434493544250262,
#  0.7619263689635385,
#  0.8124172325462012,
#  0.8453966956101329,
#  0.8705833566844383,
#  0.8918700126738519,
#  0.9219056139211975,
#  0.9458562891104533,
#  0.9637185500222699,
#  0.9835770881101631,
#  0.9999999819452222]

# %%
cm = plt.cm.get_cmap('autumn')
sc = plt.scatter(x = x, y = y, vmax = 1,  c=c, cmap = cm)
c_bar = plt.colorbar(sc)
plt.xlabel("% of even degree nodes in donor")
plt.ylabel("% of even degree nodes in acceptor")
c_bar.set_label("Average Approximation Ratio")
plt.show()
